# %% [markdown]
# # Running server and client in separate notebooks - client part
#
# Here we start the client. The server needs to be started first. Lets go....

# %%
import clientserver # import from our script

client = clientserver.Client() # Create a client instance

client.call() # start the call and print echo
# Out:
# 2024-10-24 13:17:10,800 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=72, family=2, type=1, proto=0, laddr=('127.0.0.1', 36738), raddr=('127.0.0.1', 50007)>
# 2024-10-24 13:17:10,803 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# Hello, world*
# 'Hello, world*'

# %% [markdown]
# Finished.
