# %% [markdown]
# # Running Client

# %%
import clientserver # import from our script

client = clientserver.Client() # Create a client instance

client.get_all() # start the call and print echo
# Out:
# 2024-04-15 16:41:49,878 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=77, family=2, type=1, proto=0, laddr=('127.0.0.1', 52492), raddr=('127.0.0.1', 50007)>
# 2024-04-15 16:41:49,880 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# 'sape: 4139, guido: 4127, jack: 4098'
