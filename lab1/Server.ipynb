# %% [markdown]
# # Running server and client in separate notebooks - server part
# This is the first notebook we need to run in this constelation. Note that the client notebook needs to be run now in a separate window.

# %%
import clientserver # import from our script

server = clientserver.Server() # Create a server instance

server.serve() # start server routine in the forked process
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 3
#       1 import clientserver # import from our script
# ----> 3 server = clientserver.Server() # Create a server instance
#       5 server.serve() # start server routine in the forked process
#
# File /workspaces/vs2lab/lab1/clientserver.py:25, in Server.__init__(self)
#      23 self.sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
#      24 self.sock.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)  # prevents errors due to "addresses in use"
# ---> 25 self.sock.bind((const_cs.HOST, const_cs.PORT))
#      26 self.sock.settimeout(3)  # time out in order not to block forever
#      27 self._logger.info("Server bound to socket " + str(self.sock))
#
# OSError: [Errno 98] Address already in use

# %% [markdown]
# Finished
